# %% [markdown]
# # Create Behavior Features
# ## Features based on my behavior - how and when I listen to songs and artists
#
# The first version of features is just using what comes from the raw listening data, specifically looking at frequency and recency of listening to songs and artists.
#
# The aim is to then analyse and cluster the data set to understand more about my listening behavior.
#
# Once I am happy with the first iteration I would like to visulise the results in an app (probably R Shiny).
#
# In future iterations I want to bring in external data about the music itself (genre, song length, year of release etc.) and re-run analysis and clustering.
#
# This will hopefully spark ideas for predictive and recommendation projects I can do with this data (i.e. recommend songs using others last fm data, predict what I might listen to next or look for commonality with other users (Carl!)

# %% [markdown]
# ## Technical Debt
# - Current year has been used for all datetimes as they don't come with year - what will happen when the data is more than a year old?

# %% [markdown]
# ## To-do list
#
# - (done) Tidy up play_time field to get a datetime field, being careful with the "hours ago" fields
# - (done) Make time of day/day of week features e.g. hour, day, time of day(seconds), weekend,
# - grouped time of day (requires pre-analysis)
# - Make features about the frequency and receny of songs listened to
# - Make features about the frequenct, recenct of artists
# - Make features about the distinct songs, max frequency of distinct songs, distinct song to plays ratio and % of plays that come from top song (may required analysis)
#
# Once this is done, there is hopefully enough features to do simple clustering!

# %% [markdown]
# ## Import packages

# %%
import pandas as pd # allows making dataframes of results
import numpy as np
import matplotlib.pyplot as plt # for analysis to determine which features to create
import seaborn as sns # for analysis to determine which features to create
import warnings 
warnings.filterwarnings('ignore') #stop warnings, they are annoying...
from scipy.cluster.vq import whiten
from scipy.cluster.vq import kmeans, vq
import datetime as dt

# %% [markdown]
# ## Parameters

# %%
# data filepath
download_history_path = "/Users/rosiedempsey/Desktop/MusicProject/finely_tuned/DataExports/RawScrobbles_master.csv"

# strings for classifying play_time types
minutes_string = 'minute'
hours_string = 'hour'

# scrobble year to fill in missing year in time field
scrobble_year = pd.datetime.now().year
# format of datetimes from lastfm if they are not X minutes/hours ago
datetime_format = "%Y%d%b%I:%M%p"

# where data exports to
scrobble_export_path= "/Users/rosiedempsey/Desktop/MusicProject/finely_tuned/DataExports/Scrobbleformatted.csv"
song_export_path = "/Users/rosiedempsey/Desktop/MusicProject/finely_tuned/DataExports/SongsSummary.csv"

# %% [markdown]
# ## Functions

# %%
# Functions for transforming date times

# intermediate functions
# transform datetime plays
def clean_datetime_from_datetime_plays(datetime_df):
    """
    add year to datetimes, make proper datetime field, drop temporary columns
    """
    datetime_df['play_time_year']=str(scrobble_year)+datetime_df['play_time']
    datetime_df['play_datetime'] = pd.to_datetime(datetime_df['play_time_year'],\
                                                         format=datetime_format)
    return datetime_df.drop(columns='play_time_year')

# clean plays in the form "Xunitago", unit is minutes or hours
def clean_datetime_from_ago_plays(ago_df):
    """
    Extract numbers from the time stamp field
    Fill with 1 if na, as this represents when it says "anhourago"
    Turn that into a timedelta in minutes or hours depending on the time_type field
    Subtract this from download time
    Drop calculation fields
    """
    
    ago_df['unit_ago'] = ago_df["play_time"].str.extract('(\d+)').fillna(1).astype(int)
    ago_df['unit_ago_delta'] = pd.to_timedelta(ago_df['unit_ago'], unit='h')
    ago_df.loc[ago_df['time_type']=='minutes_ago','unit_ago_delta']= pd.to_timedelta(ago_df['unit_ago'], unit='m')
    ago_df['play_datetime'] = ago_df['download_time']-ago_df['unit_ago_delta']
    
    return ago_df.drop(columns=['unit_ago','unit_ago_delta'])
    

# Transform all play times
def get_datetime_of_play(scrobble_df):
    """
    Create helper field that's say what type of playtime is given (minutes ago, hours ago or datetime-like)
    Create two dfs for different types then concat later
    For datetime types, add year to them, then transform to date time
    For non-datetimes extract the unit of time, turn into a delta then remove
    """
#     helper field of time type
    scrobble_df['time_type'] = 'datetime'
    scrobble_df.loc[scrobble_df['play_time'].str.contains(minutes_string), 'time_type'] = 'minutes_ago'
    scrobble_df.loc[scrobble_df['play_time'].str.contains(hours_string), 'time_type'] = 'hours_ago'
    
#   Take datetimes
    datetimes_raw_df = scrobble_df[scrobble_df['time_type']=='datetime']
    datetimes_clean_df = clean_datetime_from_datetime_plays(datetimes_raw_df)
    
# Take ago fields
    agotime_raw_df = scrobble_df[scrobble_df['time_type'].isin(['minutes_ago','hours_ago'])]
    agotime_clean_df = clean_datetime_from_ago_plays(agotime_raw_df)
    all_time = pd.concat([agotime_clean_df,datetimes_clean_df])
    all_time['play_date'] = all_time['play_datetime'].dt.date
    return all_time


# Create date features
def basic_date_features(scrobble_clean_df):
    """
    Must have a proper datetime field for this to work
    Take basic features from this
    Time of day in seconds, hour, day of week, weekend flag
    """
    scrobble_clean_df['time_day_secs'] = (scrobble_clean_df['play_datetime'].dt.hour*60\
                                          +scrobble_clean_df['play_datetime'].dt.minute)*60\
    + scrobble_clean_df['play_datetime'].dt.second
    scrobble_clean_df['hour'] = scrobble_clean_df['play_datetime'].dt.hour
    scrobble_clean_df['day_of_month'] = scrobble_clean_df['play_datetime'].dt.day
    scrobble_clean_df['weekday'] = scrobble_clean_df['play_datetime'].dt.weekday
    scrobble_clean_df['weekend_flag'] = np.where(scrobble_clean_df['weekday']<5,0,1)
    scrobble_clean_df['time_since_play'] = (scrobble_clean_df['download_time']-scrobble_clean_df['play_datetime']).dt.seconds
    return scrobble_clean_df

def export_data(df, export_path):
    """
    Export a versioned and master of the data
    Contains user name
    """
    df.to_csv(export_path, index=False)

# %% [markdown]
# ## Read in data

# %%
# read in hisory of scrobbles
scrobble_history = pd.read_csv(download_history_path)
# make download_time datetime
scrobble_history['download_time'] = pd.to_datetime(scrobble_history['download_time'])
scrobble_history = get_datetime_of_play(scrobble_history)
scrobble_history = basic_date_features(scrobble_history)

# %% [markdown]
# ## Really simple/most important features for now

# %%
scrobble_history['artist_count'] = scrobble_history.groupby(['artist',"username"])[['play_time']].transform(np.size)
songs = scrobble_history.groupby(["song","artist","username"]).agg({"play_time":"count","time_since_play":"max", "hour":"mean","weekday":"mean",\
                                                        "weekend_flag":"sum", 'artist_count':'max'}).reset_index()\
.rename(columns={"play_time": "total_plays", "hour":"avg_play_hour","weekday":"avg_play_day", 
                 "weekend_flag":"total_weekend_plays","artist_count":"total_artist_plays"})

# %%
artists = songs.groupby(['artist',"username"])[['song']].nunique().reset_index().rename(columns={"song": "artist_distinct_songs"})
songs = songs.merge(artists)
songs['artist_max_song_count'] = songs.groupby(['artist',"username"])[['total_plays']].transform(np.max)
songs['artist_max_song_percent'] = songs['artist_max_song_count']/songs['total_artist_plays']
songs['percent_of_artist_play'] = songs['total_plays']/songs['total_artist_plays']
songs['song_rank'] = songs.sort_values(by=['total_plays'], ascending=False) \
             .groupby(["username"]) \
             .cumcount() + 1
artists_rank = songs[['username','artist','total_artist_plays']].drop_duplicates()
artists_rank['artist_rank'] = artists_rank.groupby('username')[['total_artist_plays']].transform(lambda x: x.rank(method='min',ascending=False))
songs = songs.merge(artists_rank)
# join back to big dataframe
scrobble_history = scrobble_history.merge(songs)

# %%
# export data
export_data(scrobble_history, scrobble_export_path)
export_data(songs, song_export_path)

# %%
songs.sort_values(by='artist_rank').head()
# Out:
#                     song            artist  username  total_plays  \
# 1708            Matches   Ludovico Einaudi  COKUNUBI           37
# 1681   Cold Wind Var. 2   Ludovico Einaudi  COKUNUBI           12
# 1682              Corale  Ludovico Einaudi  COKUNUBI            2
# 1683         Dietro Casa  Ludovico Einaudi  COKUNUBI            3
# 1684  Discovery at Night  Ludovico Einaudi  COKUNUBI            2
#
#       time_since_play  avg_play_hour  avg_play_day  total_weekend_plays  \
# 1708            86343      12.621622      1.702703                    1
# 1681            80283      12.583333      1.166667                    0
# 1682            85203      13.000000      0.500000                    0
# 1683            39543       7.666667      2.333333                    0
# 1684            57243      17.500000      1.500000                    0
#
#       total_artist_plays  artist_distinct_songs  artist_max_song_count  \
# 1708                1069                     70                    116
# 1681                1069                     70                    116
# 1682                1069                     70                    116
# 1683                1069                     70                    116
# 1684                1069                     70                    116
#
#       artist_max_song_percent  percent_of_artist_play  song_rank  artist_rank
# 1708                 0.108513                0.034612         34          1.0
# 1681                 0.108513                0.011225        143          1.0
# 1682                 0.108513                0.001871       1983          1.0
# 1683                 0.108513                0.002806       1255          1.0
# 1684                 0.108513                0.001871       1973          1.0

# %%
rosie = songs[songs['username']=="rosiedempsey93"]
carl =  songs[songs['username']=="COKUNUBI"]

# %%
scrobble_history.groupby('username')[['song_rank','artist_rank']].describe()
# Out:
#                song_rank                                                  \
#                    count         mean          std  min      25%     50%
# username
# COKUNUBI          4836.0  2409.748966  1394.533718  1.0  1201.75  2408.5
# rosiedempsey93    1702.0   849.630435   491.270679  1.0   424.25   849.5
#
#                                 artist_rank                               \
#                     75%     max       count        mean         std  min
# username
# COKUNUBI        3617.25  4826.0      4836.0  253.028743  279.664976  1.0
# rosiedempsey93  1274.75  1700.0      1702.0  138.131610  144.338403  1.0
#
#
#                  25%    50%    75%    max
# username
# COKUNUBI        34.0  112.0  434.0  807.0
# rosiedempsey93  17.0   75.0  215.0  428.0

# %%
common = rosie.merge(carl,  how="inner", on=["artist","song"])
common['total_plays'] = common['total_plays_x']+common['total_plays_y']
common['min_song_rank'] =common[['song_rank_x','song_rank_y']].max(axis=1)
common['min_artist_rank'] =common[['artist_rank_x','artist_rank_y']].max(axis=1)
common.sort_values(by='song_rank_y',ascending=True )\
[["song","artist", "total_plays_x","total_plays_y","total_plays","song_rank_x","song_rank_y","min_song_rank",
  "artist_rank_x","artist_rank_y","min_artist_rank"]]
# Out:
#                                       song                  artist  \
# 109                             The Chain            Fleetwood Mac
# 37                               Well Done                   Idles
# 97                               No Brakes           The Offspring
# 105                                Dreams            Fleetwood Mac
# 29                              1049 Gotho                   Idles
# 36                                  Mother                   Idles
# 108                Never Going Back Again            Fleetwood Mac
# 106                       Go Your Own Way            Fleetwood Mac
# 31                              Date Night                   Idles
# 32                        Divide & Conquer                   Idles
# 104                            Don't Stop            Fleetwood Mac
# 135                 Nights In White Satin          The Moody Blues
# 0                                  Heroes              David Bowie
# 107                              Landslide           Fleetwood Mac
# 84                                Everlong            Foo Fighters
# 116                    For What It's Worth     Buffalo Springfield
# 145                          Superstition            Stevie Wonder
# 34                       Faith In the City                   Idles
# 35                             Heel / Heal                   Idles
# 110                   You Make Loving Fun            Fleetwood Mac
# 48                           Venus in Furs  The Velvet Underground
# 49              Knockin' on Heaven's Door                Bob Dylan
# 9                 Cherry Lips (Go Baby Go)                 Garbage
# 149                Welcome To The Get Down                   Jaden
# 60                                   Buddy               Du Blonde
# 19                             Stupid Girl                 Garbage
# 18                                 Special                 Garbage
# 15                Only Happy When It Rains                 Garbage
# 13                    I Think I'm Paranoid                 Garbage
# 141  Rule The World (I Came From The City)        Michael Kiwanuka
# ..                                     ...                     ...
# 124                                 L.S.F.                Kasabian
# 41                          Cemetry Gates               The Smiths
# 43                              Chop Suey!        System of a Down
# 59                                   Angel               Du Blonde
# 61                          Holiday Resort               Du Blonde
# 132                       Somebody to Love      Jefferson Airplane
# 133                                  Today      Jefferson Airplane
# 134                           White Rabbit      Jefferson Airplane
# 40                         Alone Again Or                     Love
# 51                All Along the Watchtower            Jimi Hendrix
# 56                    All the Small Things               blink-182
# 78                            Baba O'Riley                 The Who
# 79                          My Generation                  The Who
# 80                          Pinball Wizard                 The Who
# 50                      Tangled Up in Blue               Bob Dylan
# 83                             Basket Case               Green Day
# 81                 Back on the Chain Gang               Pretenders
# 82                     Don't Get Me Wrong               Pretenders
# 62                                   Badge                   Cream
# 63                            Strange Brew                   Cream
# 64                   Sunshine of Your Love                   Cream
# 66                           Asking for It                    Hole
# 68                                  Malibu                    Hole
# 69                     Skinny Little Bitch                    Hole
# 70                              Atmosphere            Joy Division
# 71                 Love Will Tear Us Apart            Joy Division
# 74                     Sale of the Century                 Sleeper
# 75                              Statuesque                 Sleeper
# 76                        What Do I Do Now                 Sleeper
# 67                          Celebrity Skin                    Hole
#
#      total_plays_x  total_plays_y  total_plays  song_rank_x  song_rank_y  \
# 109              1             15           16         1046          104
# 37              12              9           21           44          238
# 97               3              9           12          705          295
# 105              1              8            9         1052          345
# 29               3              7           10          608          406
# 43            4373           37.0          807.0            807.0
# 59            4440          126.0          252.0            252.0
# 61            4443          126.0          252.0            252.0
# 132           4487          150.0          104.0            150.0
# 133           4488          150.0          104.0            150.0
# 134           4490          150.0          104.0            150.0
# 40            4497          348.0          807.0            807.0
# 51            4539          168.0          434.0            434.0
# 56            4557          191.0          807.0            807.0
# 78            4620          126.0          310.0            310.0
# 79            4622          126.0          310.0            310.0
# 80            4623          126.0          310.0            310.0
# 50            4632           75.0          207.0            207.0
# 83            4676           75.0          807.0            807.0
# 81            4704           30.0          560.0            560.0
# 82            4705           30.0          560.0            560.0
# 62            4711           32.0          252.0            252.0
# 63            4713           32.0          252.0            252.0
# 64            4714           32.0          252.0            252.0
# 66            4772           26.0          369.0            369.0
# 68            4773           26.0          369.0            369.0
# 69            4774           26.0          369.0            369.0
# 70            4786           66.0          560.0            560.0
# 71            4787           66.0          560.0            560.0
# 74            4790           44.0          252.0            252.0
# 75            4791           44.0          252.0            252.0
# 76            4792           44.0          252.0            252.0
# 67            4793           26.0          369.0            369.0
#
# [150 rows x 11 columns]

# %%
common
# Out:
#                                       song                    artist  \
# 0                                  Heroes                David Bowie
# 1                           Life on Mars?                David Bowie
# 2                             Rebel Rebel                David Bowie
# 3       Scary Monsters (And Super Creeps)                David Bowie
# 4                                 Starman                David Bowie
# 5                                 #1 Crush                   Garbage
# 6                            Bad Boyfriend                   Garbage
# 7                            Bleed Like Me                   Garbage
# 8                        Blood for Poppies                   Garbage
# 9                 Cherry Lips (Go Baby Go)                   Garbage
# 10                                 Control                   Garbage
# 11                                    Dumb                   Garbage
# 12                                   Empty                   Garbage
# 13                    I Think I'm Paranoid                   Garbage
# 14                               No Horses                   Garbage
# 15                Only Happy When It Rains                   Garbage
# 16                                 Push It                   Garbage
# 17                                   Queer                   Garbage
# 18                                 Special                   Garbage
# 19                             Stupid Girl                   Garbage
# 20                              Supervixen                   Garbage
# 21                        Temptation Waits                   Garbage
# 22                 The World Is Not Enough                   Garbage
# 23                                     Vow                   Garbage
# 24                          When I Grow Up                   Garbage
# 25                      Why Do You Love Me                   Garbage
# 26                           Gimme Shelter        The Rolling Stones
# 27          (They Long to Be) Close to You           The Cranberries
# 28                                  Linger           The Cranberries
# 29                              1049 Gotho                     Idles
# ..                                     ...                       ...
# 120              I'm Shipping Up to Boston          Dropkick Murphys
# 121                               Lovefool             The Cardigans
# 122                      My Favourite Game             The Cardigans
# 123                            Just a Girl                  No Doubt
# 124                                 L.S.F.                  Kasabian
# 125                                 Layla        Derek & The Dominos
# 126                      Let Me Be The One             Matthew Sweet
# 127                     Long Train Runnin'       The Doobie Brothers
# 128                       Losing Your Mind                     Raury
# 129                 Rainy Days And Mondays                   Cracker
# 130                               Maneater   Daryl Hall & John Oates
# 131                           Waiting Room                    Fugazi
# 132                       Somebody to Love        Jefferson Airplane
# 133                                  Today        Jefferson Airplane
# 134                           White Rabbit        Jefferson Airplane
# 135                 Nights In White Satin            The Moody Blues
# 23                        22  ...                    37
# 24                        22  ...                    37
# 25                        22  ...                    37
# 26                        11  ...                     2
# 27                         5  ...                     3
# 28                         5  ...                     3
# 29                        10  ...                    75
# ..                       ...  ...                   ...
# 120                        1  ...                     2
# 121                        3  ...                     2
# 122                        3  ...                     2
# 123                        2  ...                     1
# 124                        1  ...                    13
# 125                        1  ...                     2
# 126                        2  ...                     1
# 127                        1  ...                     1
# 128                        1  ...                     1
# 129                        2  ...                     1
# 130                        1  ...                     2
# 131                        2  ...                     1
# 132                        4  ...                    21
# 133                        4  ...                    21
# 134                        4  ...                    21
# 135                        1  ...                     8
# 136                        2  ...                     1
# 137                        2  ...                     3
# 138                        1  ...                     7
# 139                        2  ...                     1
# 140                        1  ...                     1
# 141                        1  ...                    50
# 142                        1  ...                     1
# 143                        1  ...                     1
# 144                        1  ...                     7
# 145                        1  ...                    15
# 146                        1  ...                     2
# 147                        1  ...                     1
# 148                        1  ...                     4
# 149                        1  ...                     6
#
#      artist_distinct_songs_y  artist_max_song_count_y  \
# 0                          5                        4
# 1                          5                        4
# 2                          5                        4
# 3                          5                        4
# 4                          5                        4
# 5                         21                        3
# 6                         21                        3
# 7                         21                        3
# 8                         21                        3
# 9                         21                        3
# 10                        21                        3
# 11                        21                        3
# 12                        21                        3
# 13                        21                        3
# 14                        21                        3
# 15                        21                        3
# 16                        21                        3
# 17                        21                        3
# 18                        21                        3
# 19                        21                        3
# 20                        21                        3
# 21                        21                        3
# 22                        21                        3
# 23                        21                        3
# 24                        21                        3
# 25                        21                        3
# 26                         2                        1
# 27                         2                        2
# 28                         2                        2
# 29                        25                        9
# ..                       ...                      ...
# 120                        2                        1
# 121                        2                        1
# 122                        2                        1
# 123                        1                        1
# 124                       12                        2
# 125                        2                        1
# 126                        1                        1
# 127                        1                        1
# 128                        1                        1
# 129                        1                        1
# 130                        1                        2
# 131                        1                        1
# 132                       16                        2
# 133                       16                        2
# 134                       16                        2
# 135                        4                        4
# 136                        1                        1
# 137                        3                        1
# 138                        4                        3
# 139                        1                        1
# 140                        1                        1
# 141                       23                        5
# 142                        1                        1
# 143                        1                        1
# 144                        3                        4
# 145                       10                        4
# 146                        2                        1
# 147                        1                        1
# 148                        3                        2
# 149                        3                        3
#
#      artist_max_song_percent_y  percent_of_artist_play_y song_rank_y  \
# 0                     0.500000                  0.500000         778
# 1                     0.500000                  0.125000        2898
# 2                     0.500000                  0.125000        2899
# 3                     0.500000                  0.125000        2900
# 4                     0.500000                  0.125000        2901
# 5                     0.081081                  0.054054        1701
# 6                     0.081081                  0.027027        3666
# 7                     0.081081                  0.027027        3667
# 8                     0.081081                  0.054054        1692
# 9                     0.081081                  0.081081        1078
# 10                    0.081081                  0.027027        3668
# 11                    0.081081                  0.027027        3669
# 12                    0.081081                  0.027027        3670
# 13                    0.081081                  0.081081        1174
# 14                    0.081081                  0.027027        3671
# 15                    0.081081                  0.081081        1173
# 16                    0.081081                  0.054054        1627
# 127          807.0            2           3031            807.0
# 128          807.0            2           3014            807.0
# 129          807.0            2           2696            807.0
# 130          560.0            3           1735            560.0
# 131          807.0            2           3029            807.0
# 132          104.0            6           4487            150.0
# 133          104.0            2           4488            150.0
# 134          104.0            2           4490            150.0
# 135          230.0            5           1072            428.0
# 136          807.0           29           2391            807.0
# 137          434.0            2           4012            434.0
# 138          252.0            4           1982            348.0
# 139          807.0            8           2558            807.0
# 140          807.0           15           2697            807.0
# 141           61.0            3           1305            428.0
# 142          807.0            2           2735            807.0
# 143          807.0            5           2707            807.0
# 144          252.0            3           1612            428.0
# 145          145.0            5           1123            428.0
# 146          560.0            2           4159            560.0
# 147          807.0            2           2459            807.0
# 148          369.0            3           2213            369.0
# 149          278.0            4           1232            428.0
#
# [150 rows x 31 columns]

# %%
# merge back to songs data

# %% [markdown]
# ## Quick clustering

# %% [markdown]
# ## Some analysis to inform features

# %%
# most popular hour?
g = sns.FacetGrid(scrobble_history, col="username",  hue="username", size=10)
g = g.map(sns.countplot, "hour")

# %%
# wrong!
hourly_summary = scrobble_history.groupby(["username","play_date","hour"])[['song']].count().reset_index()
hourly_summary = hourly_summary.groupby(["username","hour"])[['song']].mean().reset_index()
g = sns.FacetGrid(hourly_summary, col="username",  hue="username", size=10)
g = g.map(sns.barplot, "hour", "song")

# %%
# most popular day?
g = sns.FacetGrid(scrobble_history, col="username",  hue="username", size=10)
g = g.map(sns.countplot, "weekday")

# %%
# also wrong!
weekday_summary = scrobble_history.groupby(["username","play_date","weekday"])[['song']].count().reset_index()
weekday_summary = weekday_summary.groupby(["username","weekday"])[['song']].mean().reset_index()
g = sns.FacetGrid(weekday_summary, col="username",  hue="username", size=10)
g = g.map(sns.barplot, "weekday", "song")

# %%
recent.sort_values(by='play_date', ascending=True)
# Out:
#                                                    song  \
# 4932                              California Über Alles
# 249                                               Sara
# 250                                   Edge of Seventeen
# 251                                You Make Loving Fun
# 252                                      Seven Wonders
# 253                                    Go Your Own Way
# 254                                           Landslide
# 255                                        Little Lies
# 256                                               Gypsy
# 248                                    Gold Dust Woman
# 257                                          The Chain
# 259                                            Rhiannon
# 260                                             Dreams
# 261                                          Housewife
# 262                                      Pause 4 Porno
# 263                                   Some L.A. Niggaz
# 264                                         Murder Ink
# 265                                       Bitch Niggaz
# 266                                     Let's Get High
# 258                                         Everywhere
# 267                                   Forgot About Dre
# 247                             Never Going Back Again
# 245                                          Landslide
# 4931                                      Susan's House
# 227   French Catalogues (Variation On 'The Canon In ...
# 228   Fullness Of Wind (Variation On 'The Canon In D...
# 229                                     Discreet Music
# 230                                     Think About Me
# 231                                         Peacekeeper
# 232                                                I Do
# ...                                                 ...
# 59                                        We Right Here
# 58                               One More Road To Cross
# 57                                             Slippin'
# 56                                              Prayer
# 55                                           Prayer III
# 54                                  Ruff Ryders' Anthem
# 53                                       Get At Me Dog
# 52                                    Stop Being Greedy
# 50                              What These Bitches Want
# 49                                             Blackout
# 48                                       What's My Name
# 39          COKUNUBI   datetime 2019-10-23 13:39:00.000000  2019-10-23
# 38          COKUNUBI   datetime 2019-10-23 13:43:00.000000  2019-10-23
# 37          COKUNUBI   datetime 2019-10-23 14:05:00.000000  2019-10-23
# 4844  rosiedempsey93   datetime 2019-10-23 10:18:00.000000  2019-10-23
# 36    rosiedempsey93  hours_ago 2019-10-23 15:33:48.816240  2019-10-23
# 35    rosiedempsey93  hours_ago 2019-10-23 15:33:48.816240  2019-10-23
# 34    rosiedempsey93  hours_ago 2019-10-23 15:33:48.816240  2019-10-23
# 33    rosiedempsey93  hours_ago 2019-10-23 15:33:48.816240  2019-10-23
# 32    rosiedempsey93  hours_ago 2019-10-23 18:33:48.816240  2019-10-23
# 44          COKUNUBI   datetime 2019-10-23 09:44:00.000000  2019-10-23
# 0           COKUNUBI  hours_ago 2019-10-23 19:31:03.813210  2019-10-23
#
#       time_day_secs  hour  ...  avg_play_hour  avg_play_day  \
# 4932          55320    15  ...      12.000000      1.500000
# 249           57840    16  ...      13.333333      3.000000
# 250           57480    15  ...       8.000000      2.500000
# 251           57300    15  ...      12.666667      3.000000
# 252           57060    15  ...      10.500000      2.333333
# 253           56820    15  ...      15.000000      3.600000
# 254           56640    15  ...      13.750000      3.000000
# 255           56400    15  ...      13.000000      3.000000
# 256           56160    15  ...      12.666667      3.000000
# 248           58140    16  ...       5.666667      1.666667
# 257           55860    15  ...      12.733333      3.066667
# 259           55380    15  ...      12.250000      3.500000
# 260           55080    15  ...      14.375000      3.625000
# 261           54840    15  ...      14.625000      2.000000
# 262           54720    15  ...      14.100000      2.400000
# 263           54480    15  ...      15.600000      2.400000
# 264           54300    15  ...      14.888889      2.222222
# 265           54060    15  ...      14.777778      2.222222
# 266           53880    14  ...      14.666667      2.222222
# 258           55620    15  ...      16.333333      4.000000
# 267           53700    14  ...      14.555556      2.222222
# 247           58380    16  ...       7.000000      2.000000
# 245           59040    16  ...       8.666667      1.666667
# 4931          55680    15  ...      16.666667      1.333333
# 227           65280    18  ...      18.000000      0.000000
# 228           64560    17  ...      17.000000      0.000000
# 229           62640    17  ...      17.000000      0.000000
# 230           62520    17  ...       9.500000      2.500000
# 231           62280    17  ...       9.500000      2.500000
# 232           61980    17  ...       9.500000      2.500000
# ...             ...   ...  ...            ...           ...
# 59            31620     8  ...       8.000000      2.000000
# 58            31920     8  ...       8.000000      2.000000
# 57            32160     8  ...       8.000000      2.000000
# 56            32460     9  ...       9.000000      2.000000
# 55            32640     9  ...       9.000000      2.000000
# 54            32760     9  ...       9.000000      2.000000
# 53            32940     9  ...       9.000000      2.000000
# 52            33120     9  ...       9.000000      2.000000
# 50            33600     9  ...       9.000000      2.000000
# 49            33840     9  ...       9.000000      2.000000
# 48            34140     9  ...       9.000000      2.000000
# 47            34320     9  ...       9.000000      2.000000
# 46            34560     9  ...       9.000000      2.000000
# 30            66828    18  ...      15.000000      2.750000
# 45            34860     9  ...       9.000000      2.000000
# 43            35340     9  ...       9.000000      2.000000
# 266                      10                 0.052910                0.047619
# 258                      15                 0.110294                0.044118
# 267                      10                 0.052910                0.047619
# 247                      15                 0.110294                0.036765
# 245                      15                 0.110294                0.022059
# 4931                     13                 0.481481                0.111111
# 227                       2                 0.153846                0.076923
# 228                       2                 0.153846                0.076923
# 229                       2                 0.153846                0.076923
# 230                      15                 0.110294                0.014706
# 231                      15                 0.110294                0.014706
# 232                      15                 0.110294                0.014706
# ...                     ...                      ...                     ...
# 59                        1                 0.055556                0.055556
# 58                        1                 0.055556                0.055556
# 57                        1                 0.055556                0.055556
# 56                        1                 0.055556                0.055556
# 55                        1                 0.055556                0.055556
# 54                        1                 0.055556                0.055556
# 53                        1                 0.055556                0.055556
# 52                        1                 0.055556                0.055556
# 50                        1                 0.055556                0.055556
# 49                        1                 0.055556                0.055556
# 48                        1                 0.055556                0.055556
# 47                        1                 0.055556                0.055556
# 46                        1                 0.055556                0.055556
# 30                        4                 1.000000                1.000000
# 45                        1                 0.055556                0.055556
# 43                        1                 0.055556                0.055556
# 42                        1                 0.055556                0.055556
# 41                        1                 0.250000                0.250000
# 40                       50                 0.279330                0.005587
# 39                        1                 0.250000                0.250000
# 38                       34                 0.485714                0.014286
# 37                       46                 0.335766                0.007299
# 4844                      5                 0.208333                0.041667
# 36                       28                 0.965517                0.965517
# 35                       28                 0.400000                0.400000
# 34                        8                 1.000000                1.000000
# 33                        7                 0.189189                0.189189
# 32                        3                 1.000000                1.000000
# 44                        1                 0.055556                0.055556
# 0                        13                 0.119266                0.036697
#
#       song_rank  artist_rank
# 4932        809         16.0
# 249         979         20.0
# 250        1859        434.0
# 251         989         20.0
# 252         492         20.0
# 253         549         20.0
# 254         780         20.0
# 255        1014         20.0
# 256        1008         20.0
# 248        1007         20.0
# 257         104         20.0
# 259         762         20.0
# 260         345         20.0
# 261         304          7.0
# 262         209          7.0
# 263         225          7.0
# 264         261          7.0
# 265         289          7.0
# 266         300          7.0
# 258         466         20.0
# 267         293          7.0
# 247         544         20.0
# 245        1012         20.0
# 4931        564         37.0
# 227        4466        155.0
# 228        4468        155.0
# 229        4435        155.0
# 230        1724         20.0
# 231        1725         20.0
# 232        1715         20.0
# ...         ...          ...
# 59         4152        122.0
# 58         4144        122.0
# 57         4149        122.0
# 56         4146        122.0
# 55         4147        122.0
# 54         4148        122.0
# 53         4141        122.0
# 52         4150        122.0
# 50         4153        122.0
# 49         4140        122.0
# 48         4154        122.0
# 47         4155        122.0
# 46         4145        122.0
# 30          411        255.0
# 45         4157        122.0
# 43         4156        122.0
# 42         4151        122.0
# 41         2194        369.0
# 40         3268         10.0
# 39         2141        369.0
# 38         3687         47.0
# 37         4450         19.0
# 4844       1427         51.0
# 36            6         32.0
# 35            7         10.0
# 34          120        150.0
# 33          172         18.0
# 32          695        296.0
# 44         4143        122.0
# 0           836         26.0
#
# [364 rows x 26 columns]

# %%
scrobble_history[(scrobble_history['play_datetime']>='2019-10-21')&(scrobble_history['play_datetime']<'2019-10-22')]
# 4850                1.000000         60        126.0
# 4851                0.095238        891         61.0
# 4852                0.277778        303         75.0
# 4853                1.000000        234        191.0
# 4854                0.333333        214         75.0
# 4855                0.153846        390         44.0
# 4856                1.000000        475        255.0
# 4857                0.090909        295         13.0
# 4858                0.500000        649        191.0
# 4859                1.000000        628        296.0
# 4860                0.111111        910         75.0
# 4861                0.031008        371          4.0
# 4862                1.000000        169        168.0
# 4863                0.013333       1371          9.0
# 4864                0.031008        378          4.0
# 4865                0.148148        481         37.0
# 4866                0.090909        623         21.0
# 4867                0.625000        284        150.0
# 4868                0.054054        957         18.0
# 4869                0.608696         30         55.0
# 4870                1.000000         32         98.0
#
# [26 rows x 26 columns]

# %%
recent_daily_count
# Out:
#          username   play_date  total_plays
# 0        COKUNUBI  2019-10-17            5
# 1        COKUNUBI  2019-10-18           17
# 2        COKUNUBI  2019-10-20           30
# 3        COKUNUBI  2019-10-22           39
# 4        COKUNUBI  2019-10-23           52
# 5  rosiedempsey93  2019-10-17           12
# 6  rosiedempsey93  2019-10-18            1
# 7  rosiedempsey93  2019-10-20           11
# 8  rosiedempsey93  2019-10-21           26
# 9  rosiedempsey93  2019-10-23            9

# %%
recent = scrobble_history[scrobble_history['play_date']>=dt.date.today()-dt.timedelta(days=7)].sort_values(by='play_date')
recent_daily_count = recent.groupby(["username",'play_date'])[['total_plays']].count().reset_index()
g = sns.FacetGrid(recent_daily_count.sort_values(by='play_date'), col="username",  hue="username", size=10)
g = g.map(sns.barplot, "play_date", 'total_plays' )
g.set_xticklabels(rotation=45)

# %%
# most popular day?
sns.countplot(scrobble_history["weekday"])

# %%
songs = scrobble_history.groupby(["song","artist"])[["play_time"]].count().reset_index()
artists_2 = scrobble_history.groupby(["artist"])[["play_time"]].count().reset_index()

# %%
songs.sort_values(by="play_time", ascending=False).head(20)
# Out:
#                       song                   artist  play_time
# 103                Ascent          Ludovico Einaudi         58
# 820       Low Mist Var. 1          Ludovico Einaudi         22
# 1179              Safe Now            Henry Jackman         18
# 819              Low Mist          Ludovico Einaudi         18
# 495            Fox Tracks          Ludovico Einaudi         16
# 328                Day One              Hans Zimmer         15
# 821       Low Mist Var. 2          Ludovico Einaudi         14
# 389             Duck Shoot  Rupert Gregson-Williams         14
# 525    Golden Butterflies          Ludovico Einaudi         14
# 1369       The Blue Planet              Hans Zimmer         14
# 37    A Sense of Symmetry          Ludovico Einaudi         14
# 1505                  Time              Hans Zimmer         13
# 277      Cold Wind Var. 1          Ludovico Einaudi         13
# 860               Matches          Ludovico Einaudi         13
# 1413    The Imitation Game        Alexandre Desplat         13
# 421                 Ending           Peter Sandberg         12
# 540               Gravity          Ludovico Einaudi         12
# 1648           Who's There           Peter Sandberg         11
# 1668    Would You Date Me?            Henry Jackman         10
# 894            Mobula Rays              Hans Zimmer         10

# %%
top_artist = artists_2.sort_values(by="play_time", ascending=False).head(10)
plt.figure(figsize=(16, 6))
sns.barplot(x=top_artist['artist'], y=top_artist['play_time'])
